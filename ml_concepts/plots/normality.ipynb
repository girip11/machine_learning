# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True, as_frame=True)

# %%
import seaborn as sns

sns.histplot(X, x=X.columns[0])
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='Count'>

# %%
from scipy.stats import normaltest, shapiro

shapiro(X.iloc[:, 0]), normaltest(X.iloc[:, 0])
# Out:
# (ShapiroResult(statistic=0.9760897755622864, pvalue=0.01017984002828598),
#  NormaltestResult(statistic=5.735584236235733, pvalue=0.05682424941067306))

# %%
from matplotlib import pyplot as plt
from scipy.stats import probplot

probplot(X.iloc[:, 0], dist="norm", plot=plt);

# %%
from seaborn_qqplot import pplot

pplot(
    X,
    x=X.columns[0],
    y=X.columns[1],
    kind="qq",
    height=4,
    aspect=2,
    display_kws={"identity": False, "fit": True, "reg": True, "ci": 0.025},
)
