# %% [markdown]
# # Forecasting time series

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np

# %%
_, _, off1, _ = np.random.rand(4, 4, 1)

# %%
(np.linspace(0, 1, 50) - off1).shape
# Out:
# (4, 50)

# %%
off1.shape
# Out:
# (4, 1)
